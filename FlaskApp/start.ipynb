# %%
import sport_fantasy as sf

#%load_ext lab_black
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
sf.make_subs()
# Out:
# Время замена для турнира премьер-лига Англия 25.10 еще не пришло. Сегодня 21.10
#
# Время замена для турнира премьер-лига Россия 25.10 еще не пришло. Сегодня 21.10
#
# Время замена для турнира Лига чемпионов УЕФА 22.10 еще не пришло. Сегодня 21.10
#
# Время замена для турнира бундеслига Германия 25.10 еще не пришло. Сегодня 21.10
#
# Время замена для турнира Ла Лига 25.10 еще не пришло. Сегодня 21.10
#
# Время замена для турнира серия А Италия 25.10 еще не пришло. Сегодня 21.10
#
# Время замена для турнира лига 1 Франция 25.10 еще не пришло. Сегодня 21.10
#
# Время замена для турнира высшая лига Голландия 25.10 еще не пришло. Сегодня 21.10
#
# Время замена для турнира чемпионшип 22.10 еще не пришло. Сегодня 21.10
#
# Время замена для турнира высшая лига Португалия 25.10 еще не пришло. Сегодня 21.10
#
# Делаю замены для турнира высшая лига Турция
#
# https://www.sports.ru/fantasy/football/team/json/2194816.json
# ...
